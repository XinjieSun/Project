# %%
import pandas as pd 
import numpy as np
import random

# %%
# Read in Recipies and URL
link = pd.read_csv('nutrition_info.csv')[['title','links']]

# %%
# Read in User Rating Data
data = pd.read_csv('final_rating_data.csv')
data = data.drop(columns=['Unnamed: 0'])
data.head()
# Out:
#    10 Minute Healthy Crispy Chicken and avocado Wraps  ...  Zesty Quinoa with Broccoli and Cashews
# 0                                                NaN   ...                                     NaN
# 1                                                NaN   ...                                     NaN
# 2                                                NaN   ...                                     NaN
# 3                                                NaN   ...                                     NaN
# 4                                                NaN   ...                                     1.0
#
# [5 rows x 265 columns]

# %%
def user_input(data,link):
    # USER 1: 
    print('==================================================================')
    print('User1 Inputs:')
    print('==================================================================')
    # Generate Random recipies to rate
    dic = {}
    for x in range(10):
        index = random.randint(0,len(data.columns))
        recipie = data.columns[index]
        print(recipie,' : ',link.links[link['title']==recipie].values[0])
        rating = input('Enter Rating (1-5 stars): ')
        dic[recipie] = float(rating)
    # Unpack Rating and concat into main dataframe
    user = data.iloc[0]
    user[:] = np.nan
    for key,value in dic.items():
        user[key] = value
    temp = pd.DataFrame([user], index = ['user1'])
    df1 = pd.concat([temp, data])
    
    # USER 2:
    print('==================================================================')
    print('User2 Inputs:')
    print('==================================================================')
    # Generate Random recipies to rate
    dic = {}
    for x in range(10):
        index = random.randint(0,len(data.columns))
        recipie = data.columns[index]
        print(recipie,' : ',link.links[link['title']==recipie].values[0])
        rating = input('Enter Rating (1-5 stars): ')
        dic[recipie] = float(rating)
    # Unpack Rating and concat into main dataframe
    user = data.iloc[0]
    user[:] = np.nan
    for key,value in dic.items():
        user[key] = value
    temp = pd.DataFrame([user], index = ['user2'])
    final_df = pd.concat([temp, df1])
    return final_df

# %%
# Obtain User 1 & 2 Ratings
df = user_input(data,link)
# Out:
# ==================================================================
# User1 Inputs:
# ==================================================================
# Baked Macaroni and Cheese  :  https://www.yummly.com/recipe/Baked-Macaroni-and-Cheese-2221642
# Enter Rating (1-5 stars): 5
# Parmesan Crusted Baked Pork Chops  :  https://www.yummly.com/recipe/Parmesan-Crusted-Baked-Pork-Chops-2465569
# Enter Rating (1-5 stars): 4
# Chinese Broccoli Beef  :  https://www.yummly.com/recipe/Chinese-Broccoli-Beef-2306934
# Enter Rating (1-5 stars): 5
# Thai Salmon  :  https://www.yummly.com/recipe/Thai-Salmon-2408300
# Enter Rating (1-5 stars): 4
# Quinoa Power Salad  :  https://www.yummly.com/recipe/Quinoa-Power-Salad-1856889
# Enter Rating (1-5 stars): 3
# Curried Quinoa  :  https://www.yummly.com/recipe/Curried-Quinoa-1588231
# Enter Rating (1-5 stars): 5
# 20-Minute Lemon Pesto Penne  :  https://www.yummly.com/recipe/20-Minute-Lemon-Pesto-Penne-2314173
# Enter Rating (1-5 stars): 2
# Light Orange Cake  :  https://www.yummly.com/recipe/Light-Orange-Cake-782468
# Enter Rating (1-5 stars): 4
# Parmesan Crusted Chicken  :  https://www.yummly.com/recipe/Parmesan-crusted-chicken-300048
# Enter Rating (1-5 stars): 5
# Cream of Mushroom Pork Chops BAKED  :  https://www.yummly.com/recipe/Cream-of-Mushroom-Pork-Chops-BAKED-2643698
# Enter Rating (1-5 stars): 2
# ==================================================================
# User2 Inputs:
# ==================================================================
# The Best Chili on Earth  :  https://www.yummly.com/recipe/The-Best-Chili-on-Earth-2329456
# Enter Rating (1-5 stars): 3
# Super Savory Vegetarian “Meatballs”  :  https://www.yummly.com/recipe/Super-Savory-Vegetarian-Meatballs-2633682
# Enter Rating (1-5 stars): 2
# Moroccan Quinoa  :  https://www.yummly.com/recipe/Moroccan-Quinoa-510541
# Enter Rating (1-5 stars): 3
# Overnight Quinoa  :  https://www.yummly.com/recipe/Overnight-Quinoa-2044317
# Enter Rating (1-5 stars): 4
# Spicy Chicken Breasts  :  https://www.yummly.com/recipe/Spicy-Chicken-Breasts-2278373
# Enter Rating (1-5 stars): 5
# Honey Soy Chicken Breasts  :  https://www.yummly.com/recipe/Honey-Soy-Chicken-Breasts-2192893
# Enter Rating (1-5 stars): 3
# Broccoli Cauliflower Casserole  :  https://www.yummly.com/recipe/Broccoli-Cauliflower-Casserole-2263038
# Enter Rating (1-5 stars): 4
# Black Bean-Quinoa Buddha Bowl  :  https://www.yummly.com/recipe/Black-Bean-Quinoa-Buddha-Bowl-2227717
# Enter Rating (1-5 stars): 5
# 5-Ingredient Pesto Salmon  :  https://www.yummly.com/recipe/5-Ingredient-Pesto-Salmon-2440805
# Enter Rating (1-5 stars): 3
# Parmesan Crusted Baked Pork Chops  :  https://www.yummly.com/recipe/Parmesan-Crusted-Baked-Pork-Chops-2465569
# Enter Rating (1-5 stars): 5

# %%
df.head()
# Out:
#        10 Minute Healthy Crispy Chicken and avocado Wraps  ...  Zesty Quinoa with Broccoli and Cashews
# user2                                                NaN   ...                                     NaN
# user1                                                NaN   ...                                     NaN
# 0                                                    NaN   ...                                     NaN
# 1                                                    NaN   ...                                     NaN
# 2                                                    NaN   ...                                     NaN
#
# [5 rows x 265 columns]

# %%
from fancyimpute import SoftImpute, BiScaler, NuclearNormMinimization

# %%
df.values
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [ 4., nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])

# %%
df_normalized = BiScaler().fit_transform(df.values)
df_normalized
# Out:
# [BiScaler] Initial log residual value = 8.948899
# [BiScaler] Iter 1: log residual = 0.640021, log improvement ratio=8.308878
# [BiScaler] Iter 2: log residual = -1.546002, log improvement ratio=2.186023
# [BiScaler] Iter 3: log residual = -3.401307, log improvement ratio=1.855305
# [BiScaler] Iter 4: log residual = -5.040913, log improvement ratio=1.639606
# [BiScaler] Iter 5: log residual = -6.545215, log improvement ratio=1.504302
# [BiScaler] Iter 6: log residual = -7.959244, log improvement ratio=1.414028
# [BiScaler] Iter 7: log residual = -9.312927, log improvement ratio=1.353683
# [BiScaler] Iter 8: log residual = -10.626393, log improvement ratio=1.313466
# [BiScaler] Iter 9: log residual = -11.912738, log improvement ratio=1.286346
# [BiScaler] Iter 10: log residual = -13.180442, log improvement ratio=1.267704
# [BiScaler] Iter 11: log residual = -14.435087, log improvement ratio=1.254645
# [BiScaler] Iter 12: log residual = -15.680427, log improvement ratio=1.245340
# [BiScaler] Iter 13: log residual = -16.919039, log improvement ratio=1.238611
# [BiScaler] Iter 14: log residual = -18.152712, log improvement ratio=1.233674
# [BiScaler] Iter 15: log residual = -19.382712, log improvement ratio=1.230000
# [BiScaler] Iter 16: log residual = -20.609940, log improvement ratio=1.227228
# [BiScaler] Iter 17: log residual = -21.835048, log improvement ratio=1.225108
# [BiScaler] Iter 18: log residual = -23.058513, log improvement ratio=1.223465
# [BiScaler] Iter 19: log residual = -24.280687, log improvement ratio=1.222174
# [BiScaler] Iter 20: log residual = -25.501835, log improvement ratio=1.221148
# [BiScaler] Iter 21: log residual = -26.722155, log improvement ratio=1.220320
# [BiScaler] Iter 22: log residual = -27.941800, log improvement ratio=1.219645
# [BiScaler] Iter 23: log residual = -29.160887, log improvement ratio=1.219087
# [BiScaler] Iter 24: log residual = -30.379506, log improvement ratio=1.218619
# [BiScaler] Iter 25: log residual = -31.597726, log improvement ratio=1.218220
# [BiScaler] Iter 26: log residual = -32.815601, log improvement ratio=1.217876
# [BiScaler] Iter 27: log residual = -34.033174, log improvement ratio=1.217573
# [BiScaler] Iter 28: log residual = -35.250477, log improvement ratio=1.217302
# [BiScaler] Iter 29: log residual = -36.467533, log improvement ratio=1.217057
# [BiScaler] Iter 30: log residual = -37.684364, log improvement ratio=1.216830
# [BiScaler] Iter 31: log residual = -38.900979, log improvement ratio=1.216616
# [BiScaler] Iter 32: log residual = -40.117395, log improvement ratio=1.216415
# [BiScaler] Iter 33: log residual = -41.333610, log improvement ratio=1.216215
# [BiScaler] Iter 34: log residual = -42.549632, log improvement ratio=1.216023
# [BiScaler] Iter 35: log residual = -43.765455, log improvement ratio=1.215822
# [BiScaler] Iter 36: log residual = -44.981109, log improvement ratio=1.215654
# [BiScaler] Iter 37: log residual = -46.196552, log improvement ratio=1.215443
# [BiScaler] Iter 38: log residual = -47.411802, log improvement ratio=1.215250
# [BiScaler] Iter 39: log residual = -48.626844, log improvement ratio=1.215042
# [BiScaler] Iter 40: log residual = -49.841636, log improvement ratio=1.214792
# [BiScaler] Iter 41: log residual = -51.056315, log improvement ratio=1.214679
# [BiScaler] Iter 42: log residual = -52.271282, log improvement ratio=1.214967
# [BiScaler] Iter 43: log residual = -53.486635, log improvement ratio=1.215353
# [BiScaler] Iter 44: log residual = -54.699612, log improvement ratio=1.212977
# [BiScaler] Iter 45: log residual = -55.914050, log improvement ratio=1.214438
# [BiScaler] Iter 46: log residual = -57.109482, log improvement ratio=1.195432
# [BiScaler] Iter 47: log residual = -58.300052, log improvement ratio=1.190571
# [BiScaler] Iter 48: log residual = -59.392349, log improvement ratio=1.092297
# [BiScaler] Iter 49: log residual = -60.340974, log improvement ratio=0.948625
# [BiScaler] Iter 50: log residual = -61.381292, log improvement ratio=1.040318
# [BiScaler] Iter 51: log residual = -61.488404, log improvement ratio=0.107112
# [BiScaler] Iter 52: log residual = -62.450679, log improvement ratio=0.962274
# [BiScaler] Iter 53: log residual = -60.943606, log improvement ratio=-1.507072
# array([[        nan,         nan,         nan, ...,         nan,
#                 nan,         nan],
#        [        nan,         nan,         nan, ...,         nan,
#                 nan,         nan],
#        [        nan,         nan,         nan, ...,         nan,
#                 nan,         nan],
#        ...,
#        [-1.09381955,         nan,         nan, ...,         nan,
#                 nan,         nan],
#        [        nan,         nan,         nan, ...,         nan,
#                 nan,         nan],
#        [        nan,         nan,         nan, ...,         nan,
#                 nan,         nan]])

# %%
df_filled = pd.DataFrame(SoftImpute().fit_transform(df_normalized))
# Out:
# [SoftImpute] Max Singular Value of X_init = 10.856399
# [SoftImpute] Iter 1: observed MAE=0.024014 rank=105
# [SoftImpute] Iter 2: observed MAE=0.023988 rank=105
# [SoftImpute] Iter 3: observed MAE=0.023977 rank=105
# [SoftImpute] Iter 4: observed MAE=0.023968 rank=105
# [SoftImpute] Iter 5: observed MAE=0.023960 rank=105
# [SoftImpute] Iter 6: observed MAE=0.023951 rank=105
# [SoftImpute] Iter 7: observed MAE=0.023942 rank=105
# [SoftImpute] Iter 8: observed MAE=0.023933 rank=105
# [SoftImpute] Iter 9: observed MAE=0.023923 rank=105
# [SoftImpute] Iter 10: observed MAE=0.023913 rank=105
# [SoftImpute] Iter 11: observed MAE=0.023903 rank=105
# [SoftImpute] Iter 12: observed MAE=0.023892 rank=105
# [SoftImpute] Iter 13: observed MAE=0.023881 rank=105
# [SoftImpute] Iter 14: observed MAE=0.023870 rank=105
# [SoftImpute] Iter 15: observed MAE=0.023858 rank=105
# [SoftImpute] Iter 16: observed MAE=0.023846 rank=105
# [SoftImpute] Iter 17: observed MAE=0.023833 rank=105
# [SoftImpute] Iter 18: observed MAE=0.023820 rank=105
# [SoftImpute] Iter 19: observed MAE=0.023807 rank=105
# [SoftImpute] Iter 20: observed MAE=0.023794 rank=105
# [SoftImpute] Iter 21: observed MAE=0.023780 rank=105
# [SoftImpute] Iter 22: observed MAE=0.023766 rank=105
# [SoftImpute] Iter 23: observed MAE=0.023751 rank=105
# [SoftImpute] Iter 24: observed MAE=0.023735 rank=105
# [SoftImpute] Iter 25: observed MAE=0.023704 rank=104
# [SoftImpute] Iter 26: observed MAE=0.023667 rank=104
# [SoftImpute] Iter 27: observed MAE=0.023649 rank=104
# [SoftImpute] Iter 28: observed MAE=0.023609 rank=103
# [SoftImpute] Iter 29: observed MAE=0.023584 rank=103
# [SoftImpute] Iter 30: observed MAE=0.023569 rank=103
# [SoftImpute] Iter 31: observed MAE=0.023545 rank=102
# [SoftImpute] Iter 32: observed MAE=0.023502 rank=102
# [SoftImpute] Iter 33: observed MAE=0.023484 rank=102
# [SoftImpute] Iter 34: observed MAE=0.023438 rank=101
# [SoftImpute] Iter 35: observed MAE=0.023400 rank=100
# [SoftImpute] Iter 36: observed MAE=0.023356 rank=100
# [SoftImpute] Iter 37: observed MAE=0.023338 rank=100
# [SoftImpute] Iter 38: observed MAE=0.023323 rank=100
# [SoftImpute] Iter 39: observed MAE=0.023265 rank=98
# [SoftImpute] Iter 40: observed MAE=0.023210 rank=98
# [SoftImpute] Iter 41: observed MAE=0.023164 rank=97
# [SoftImpute] Iter 42: observed MAE=0.023127 rank=96
# [SoftImpute] Iter 43: observed MAE=0.023086 rank=96
# [SoftImpute] Iter 44: observed MAE=0.023069 rank=96
# [SoftImpute] Iter 45: observed MAE=0.023017 rank=94
# [SoftImpute] Iter 46: observed MAE=0.022970 rank=94
# [SoftImpute] Iter 47: observed MAE=0.022952 rank=94
# [SoftImpute] Iter 48: observed MAE=0.022920 rank=93
# [SoftImpute] Iter 49: observed MAE=0.022891 rank=93
# [SoftImpute] Iter 50: observed MAE=0.022877 rank=93
# [SoftImpute] Iter 51: observed MAE=0.022865 rank=93
# [SoftImpute] Iter 52: observed MAE=0.022831 rank=92
# [SoftImpute] Iter 53: observed MAE=0.022786 rank=91
# [SoftImpute] Iter 54: observed MAE=0.022746 rank=91
# [SoftImpute] Iter 55: observed MAE=0.022729 rank=91
# [SoftImpute] Iter 56: observed MAE=0.022707 rank=90
# [SoftImpute] Iter 57: observed MAE=0.022668 rank=89
# [SoftImpute] Iter 58: observed MAE=0.022626 rank=89
# [SoftImpute] Iter 59: observed MAE=0.022610 rank=89
# [SoftImpute] Iter 60: observed MAE=0.022599 rank=89
# [SoftImpute] Iter 61: observed MAE=0.022589 rank=89
# [SoftImpute] Iter 62: observed MAE=0.022579 rank=89
# [SoftImpute] Iter 63: observed MAE=0.022553 rank=88
# [SoftImpute] Iter 64: observed MAE=0.022500 rank=86
# [SoftImpute] Iter 65: observed MAE=0.022436 rank=86
# [SoftImpute] Iter 66: observed MAE=0.022416 rank=86
# [SoftImpute] Iter 67: observed MAE=0.022405 rank=86
# [SoftImpute] Iter 68: observed MAE=0.022396 rank=86
# [SoftImpute] Iter 69: observed MAE=0.022388 rank=86
# [SoftImpute] Iter 70: observed MAE=0.022380 rank=86
# [SoftImpute] Iter 71: observed MAE=0.022350 rank=85
# [SoftImpute] Iter 72: observed MAE=0.022328 rank=85
# [SoftImpute] Iter 73: observed MAE=0.022317 rank=85
# [SoftImpute] Iter 74: observed MAE=0.022309 rank=85
# [SoftImpute] Iter 75: observed MAE=0.022269 rank=84
# [SoftImpute] Iter 76: observed MAE=0.022253 rank=84
# [SoftImpute] Iter 77: observed MAE=0.022229 rank=83
# [SoftImpute] Iter 78: observed MAE=0.022204 rank=83
# [SoftImpute] Iter 79: observed MAE=0.022187 rank=82
# [SoftImpute] Iter 80: observed MAE=0.022158 rank=82
# [SoftImpute] Iter 81: observed MAE=0.022147 rank=82
# [SoftImpute] Iter 82: observed MAE=0.022139 rank=82
# [SoftImpute] Iter 83: observed MAE=0.022133 rank=82
# [SoftImpute] Iter 84: observed MAE=0.022128 rank=82
# [SoftImpute] Iter 85: observed MAE=0.022123 rank=82
# [SoftImpute] Iter 86: observed MAE=0.022117 rank=82
# [SoftImpute] Iter 87: observed MAE=0.022110 rank=81
# [SoftImpute] Iter 88: observed MAE=0.022074 rank=81
# [SoftImpute] Iter 89: observed MAE=0.022061 rank=81
# [SoftImpute] Iter 90: observed MAE=0.022053 rank=81
# [SoftImpute] Iter 91: observed MAE=0.022047 rank=81
# [SoftImpute] Iter 92: observed MAE=0.022042 rank=81
# [SoftImpute] Iter 93: observed MAE=0.022037 rank=81
# [SoftImpute] Iter 94: observed MAE=0.022032 rank=81
# [SoftImpute] Iter 95: observed MAE=0.022027 rank=81
# [SoftImpute] Iter 96: observed MAE=0.022022 rank=81
# [SoftImpute] Iter 97: observed MAE=0.022017 rank=81
# [SoftImpute] Iter 98: observed MAE=0.022012 rank=81
# [SoftImpute] Iter 99: observed MAE=0.022003 rank=80
# [SoftImpute] Iter 100: observed MAE=0.021976 rank=80
# [SoftImpute] Stopped after iteration 100 for lambda=0.217128

# %%
df_filled
# Out:
#           0         1         2    ...       262       263       264
# 0   -0.245779  0.437528  0.389271  ... -0.076223 -0.331345  0.206078
# 1    0.090919 -0.241401 -0.018308  ...  0.069642 -0.035596 -0.180850
# 2    0.090919 -0.241401 -0.018308  ...  0.069642 -0.035596 -0.180850
# 3    0.050286 -0.417925  0.162184  ...  0.096862  0.243654 -0.347007
# 4   -0.006739  0.099993  0.552016  ... -0.047367 -0.193772 -0.197029
# ..        ...       ...       ...  ...       ...       ...       ...
# 102  0.301616 -0.261394  0.126754  ...  0.220899 -0.232281 -0.110278
# 103  0.189684 -0.164195 -0.021685  ... -0.045371  0.673861 -0.170547
# 104 -1.093820 -0.207525 -0.313564  ...  0.055071  0.157863 -0.032524
# 105  0.268773 -0.319758 -0.010201  ... -0.086619 -0.390460  0.074800
# 106  0.341217  0.399731 -0.804688  ...  0.045603 -0.160806 -0.201833
#
# [107 rows x 265 columns]

# %%
# User 2 Ratings
df_filled[0]
# Out:
# 0      1.779838
# 1      1.250956
# 2      1.250956
# 3      3.191354
# 4      2.981645
#          ...
# 102    3.577051
# 103    3.308410
# 104    4.000000
# 105    3.275185
# 106    2.522586
# Name: 0, Length: 107, dtype: float64

# %%
# User 1 Ratings
df_filled[1]
# Out:
# 0      1.958590
# 1      1.384962
# 2      1.384962
# 3      4.825359
# 4      4.627623
#          ...
# 102    4.283788
# 103    4.797153
# 104    4.026825
# 105    3.759101
# 106    4.146409
# Name: 1, Length: 107, dtype: float64

# %%
# Use 3 nearest rows which have a feature to fill in each row's missing features
X_filled_NNM = pd.DataFrame(NuclearNormMinimization().fit_transform(df))
# Out:
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 220995
# eps = 1.00e-04, alpha = 1.50, max_iters = 50000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 126088, constraints m = 182798
# Cones:	primal zero / dual free vars: 28355
# 	linear vars: 85065
# 	sd vars: 69378, sd blks: 1
# Setup time: 2.82e-01s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 4.57e+21  4.49e+21  1.00e+00 -1.37e+25  3.25e+24  4.55e+24  1.28e-01
#    100| 1.79e-04  1.74e-04  3.42e-05  1.16e+03  1.16e+03  2.22e-13  1.36e+01
#    140| 6.14e-05  6.83e-05  1.32e-05  1.16e+03  1.16e+03  2.67e-15  1.88e+01
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 1.88e+01s
# 	Lin-sys: nnz in L factor: 534802, avg solve time: 4.14e-03s
# 	Cones: avg projection time: 7.88e-02s
# 	Acceleration: avg step time: 4.19e-02s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 9.8981e-10, dist(y, K*) = 1.6222e-08, s'y/|s||y| = 6.9969e-14
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 6.1445e-05
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 6.8338e-05
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 1.3231e-05
# ----------------------------------------------------------------------------
# c'x = 1164.1077, -b'y = 1164.0769
# ============================================================================

# %%
X_filled_NNM
# Out:
#           0         1         2    ...       262       263       264
# 0    2.888393  3.443279  3.514189  ...  2.232274  2.937280  2.437654
# 1    2.861330  2.879315  2.961133  ...  2.293654  2.720616  0.921138
# 2    2.861330  2.879315  2.961133  ...  2.293654  2.720616  0.921138
# 3    4.565196  4.502747  4.937946  ...  3.780351  4.695044  2.058160
# 4    4.491077  4.863496  5.000000  ...  3.472587  4.563870  3.095495
# ..        ...       ...       ...  ...       ...       ...       ...
# 102  4.538308  4.385889  4.324317  ...  3.941551  4.156875  2.692454
# 103  4.325200  4.730618  4.500237  ...  3.560953  5.000000  2.730188
# 104  4.000000  4.070876  4.276285  ...  3.475371  4.277673  2.953719
# 105  4.115767  4.181813  3.672387  ...  2.970011  4.228657  2.614891
# 106  4.045936  4.673407  3.987260  ...  3.409220  4.359107  2.526202
#
# [107 rows x 265 columns]

# %%
df_filled.to_csv('filled_ratings.csv',index=False)
