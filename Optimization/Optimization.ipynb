# %%
import json
import pandas as pd 
import numpy as np
import ast
import random
from fancyimpute import SoftImpute, BiScaler
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 1. Read Offline Scraped Data and Calculate Prices

# %%
data = pd.read_csv('nutrition_info.csv')
temp = [ast.literal_eval(i) for i in data['ingredients']]
data['ingredients'] = temp
data = data.drop(columns=['Unnamed: 0','personal_rating'])

# %%
# find all the major ingredients
key_words = list(['pound', 'lb', 'pounds', 'kg', 'cup', 'cups', 'ounces', 'package', None])
major_ingredients = [[]for i in range(len(data.ingredients))]
for ing in range(len(data.ingredients)):
    for i in data.ingredients[ing]:
        if any(key_word in i for key_word in key_words):
            major_ingredients[ing].append(i)

# %%
def get_prices(data,file):
    # Read JSON price File
    with open(file, 'r') as myfile:
        temp=myfile.read()
    price = json.loads(temp)
    # Compute prices of each recipie with corresponding ingredients and prices
    arr = []
    for i in major_ingredients:
        total = 0
        for ingredient in i:
            try:
                if type(price[ingredient[2]])==float:
                    total += float(price[ingredient[2]])
                else:
                    total += float(price[ingredient[2]].replace('$',''))
            except:
                pass
        arr.append(total*1.2)
    return arr

# %%
amazon = get_prices(data,'prices_amazon.json')
walmart = get_prices(data,'prices_walmart.json')
wholefoods = get_prices(data,'prices_wholefoods.json')
data['amazon'] = amazon
data['walmart'] = walmart
data['wholefoods'] = wholefoods
data
# Out:
#                                                  title  rating  cook_time  \
# 0                                     Quinoa Tabbouleh     4.5         60
# 1                                          Thai Salmon     4.0         21
# 2           Coconut Curry Carrot and Sweet Potato Soup     4.0         35
# 3                               Korean Vegetarian Beef     4.5         20
# 4     Braised Chickpeas with Tomato, Spinach, and Feta     4.5         20
# 5                     Tuscan Kale With Garlic Tomatoes     4.5         40
# 6                      5-Ingredient Cheese Naan Pizzas     4.5         17
# 7                                 Oven Baked Pork Chop     4.5        180
# 8            White Chocolate-Raspberry Blender Muffins     4.0         25
# 9                             Perfect Air Fryer Salmon     4.5         40
# 10                             Vegetarian Chimichangas     4.0         25
# 11                                Garlic Butter Shrimp     4.5         20
# 12                                     Mexican Lasagna     4.0         50
# 13                              Bacon Cheeseburger Dip     3.0         21
# 14                           Best Green Bean Casserole     4.5         30
# 15                                 Hamburger Casserole     4.5         60
# 16                            Bacon Ranch Potato Salad     4.5         15
# 17                                       Chicken Curry     4.0         20
# 18                                 Crisp Bean Burritos     4.5         40
# 19                                      Mongolian Beef     4.5         20
# 20               Sweet and Sour Glazed Chicken Breasts     4.5         35
# 21                                Breakfast Toast Cups     4.5         35
# 22                       Easy Garlic-Herb Baked Salmon     4.5         20
# 23                          Italian Crescent Casserole     4.5         35
# 24                                   Bubba Gump Shrimp     4.5         20
# 25                                  Breakfast Taquitos     4.5         35
# 26                                  Maple Dijon Salmon     4.5         35
# 27          Low-Carb Zucchini Bake with Feta and Thyme     4.0         50
# 28                   Parmesan Crusted Baked Pork Chops     4.5         35
# 29                                           Miso Soup     4.5         25
# ..                                                 ...     ...        ...
# 238                      Baked Buffalo Chicken Tenders     4.5         95
# 239                                     Curried Quinoa     4.0         30
# 240                             Thai Spicy Noodle Soup     4.5         25
# 241                                      QUINOA BURGER     4.5         40
# 242                        Quick Margherita Naan Pizza     5.0         19
# 243                        On-The-Go Breakfast Muffins     4.5         30
# 244                                Frozen Oreo Dessert     4.5         30
# 245                             Amazingly Moist Salmon     4.5         17
# 246                                     Healthy Hummus     4.0          8
# 247                            Weight Loss Wonder Soup     4.5        120
# 248                            Easy Pan-Seared Chicken     4.5         30
# 249                       Loaded Cauliflower Casserole     4.5         35
# 250                                     Quinoa Risotto     4.0         20
# 251             Juicy Oven-Baked Cajun Chicken Breasts     4.5         30
# 252                                Tater Tot Casserole     4.5         55
# 253                           Garlic Butter Pork Chops     4.5         20
# 254        Healthy 5-Ingredient Flourless Banana Bread     4.5         25
# 255                          Parmesan Baked Pork Chops     4.5         50
# 256                             Classic Macaroni Salad     4.5         25
# 257                            5-Ingredient Pound Cake     4.5         92
# 258                              Breakfast Quesadillas     4.0         25
# 259                                    Christmas Crack     4.5         60
# 260                   Blueberry Brain Healthy Smoothie     4.5         15
# 261                                 Chocolate Mug Cake     4.5         15
# 262                  No-bake Raspberry Cheesecake Pots     3.0         60
# 263                             Banana Breakfast Drink     4.5          8
# 264  Easy Chicken Broccoli Casserole In Under 30 Mi...     4.5         30
# 265                                 Firecracker Salmon     4.5         25
# 266                 Cheesy Egg And Hashbrown Casserole     4.5         50
# 267                  15-Minute Baked Salmon with Lemon     4.5         15
#
#      calories  sodium    fat  protein  carbs  fiber  \
# 0       310.0   610.0   16.0      8.0   37.0    6.0
# 1        80.0   370.0    3.5      6.0    5.0    1.0
# 2       250.0   600.0   18.0      3.0   22.0    6.0
# 3       840.0   920.0    9.0     15.0  171.0    3.0
# 4       440.0  1830.0   23.0     15.0   48.0   10.0
# 5       130.0    10.0   11.0      1.0    7.0    1.0
# 6        80.0   150.0    3.0      4.0    9.0    0.0
# 7       290.0   910.0   17.0     20.0   15.0    0.0
# 8       200.0   170.0    5.0      6.0   33.0    5.0
# 9       310.0   460.0   20.0     24.0   10.0    5.0
# 10      460.0  1330.0   16.0     16.0   66.0   11.0
# 11      160.0   370.0    6.0     23.0    4.0    1.0
# 12      280.0   160.0   11.0     24.0   20.0    3.0
# 13     1500.0  1490.0  153.0     26.0    4.0    1.0
# 14      420.0   840.0   25.0     15.0   36.0    7.0
# 15      910.0   850.0   35.0     51.0   96.0    5.0
# 16      380.0   600.0   26.0     16.0   21.0    3.0
# 17      470.0   200.0   35.0     29.0   16.0    6.0
# 18      560.0   550.0   52.0     10.0   14.0    5.0
# 19      390.0  1510.0   15.0     34.0   27.0    1.0
# 20      320.0   690.0    6.0     54.0    9.0    0.0
# 21      290.0   630.0   20.0     13.0   14.0    1.0
# 22      270.0   360.0   18.0     23.0    4.0    1.0
# 23      530.0   760.0   31.0     27.0   35.0    4.0
# 24      210.0   170.0   23.0      1.0    2.0    1.0
# 25      560.0   650.0   36.0     24.0   40.0    8.0
# 26      380.0   260.0   24.0     24.0   16.0    1.0
# 27      160.0   480.0   12.0      8.0    6.0    1.0
# 28      430.0   860.0   35.0     22.0    5.0    1.0
# 29      200.0  1450.0   10.0     19.0   12.0    4.0
# ..        ...     ...    ...      ...    ...    ...
# 238     200.0   340.0   11.0     19.0    4.0    0.0
# 239     200.0   170.0    4.5      7.0   34.0    5.0
# 240     410.0   970.0   34.0      5.0   25.0    3.0
# 241     500.0   690.0   21.0     24.0   55.0    7.0
# 242      50.0   135.0    0.5      2.0   10.0    0.0
# 243     180.0   310.0   14.0     11.0    2.0    0.0
# 244     150.0    70.0    9.0      2.0   15.0    1.0
# 245     290.0   340.0   19.0     23.0    5.0    1.0
# 246     190.0   620.0    9.0      5.0   23.0    5.0
# 247     120.0   120.0    0.0      5.0   25.0    9.0
# 248     350.0   560.0   14.0     49.0    6.0    0.0
# 249     250.0   480.0   22.0     10.0    5.0    1.0
# 250     340.0   470.0   10.0     14.0   49.0    7.0
# 251     320.0   550.0   11.0     52.0    3.0    1.0
# 252     460.0   960.0   28.0     18.0   36.0    3.0
# 253     520.0   310.0   34.0     50.0    1.0    0.0
# 254     130.0   140.0    2.0      4.0   25.0    3.0
# 255     530.0  1020.0   24.0     54.0   22.0    2.0
# 256    1050.0  1360.0   97.0      7.0   38.0    3.0
# 257     290.0   160.0   17.0      4.0   31.0    1.0
# 258     220.0   360.0   14.0      9.0   13.0    1.0
# 259    1320.0   350.0   91.0      9.0  136.0    8.0
# 260     370.0    55.0   22.0      9.0   38.0    6.0
# 261     140.0   115.0    6.0      1.0   20.0    1.0
# 262     200.0   250.0   12.0      4.0   21.0    3.0
# 263     240.0   160.0   12.0     10.0   25.0    3.0
# 264     230.0   360.0   11.0     28.0    4.0    1.0
# 265     520.0  1070.0   36.0     35.0    9.0    1.0
# 266     300.0   580.0   20.0     14.0   16.0    1.0
# 267     270.0   360.0   18.0     23.0    5.0    2.0
#
#                                            ingredients  \
# 0    [[1, cup, quinoa], [1, None, lemon], [4, clove...
# 1    [[6, ounces, salmon fillets], [1, pinch, salt]...
# 2    [[1, tablespoon, coconut oil], [1, None, yello...
# 3    [[1, package, veggie ground round], [1/2, cup,...
# 4    [[3, tablespoons, extra virgin olive oil], [5,...
# 5    [[1, None, Tuscan kale], [4, tablespoons, extr...
# 6    [[4, pieces, naan], [2, teaspoons, olive oil],...
# 7    [[None, None, pork chops], [1, tablespoon, soy...
# 8    [[2, cups, old-fashioned oats], [2, None, eggs...
# 9    [[2, None, salmon fillets], [2, teaspoons, avo...
# 10   [[1, None, onion], [4, None, garlic cloves], [...
# 11   [[1, tablespoon, olive oil], [1, pound, shrimp...
# 12   [[2, tablespoons, olive oil], [2, None, zucchi...
# 13   [[8, ounces, ground beef], [2, cups, shredded ...
# 14   [[29, ounces, green beans], [10 3/4, ounces, c...
# 15   [[1, pound, shells], [1, pound, hamburger], [2...
# 16   [[2, pounds, potatoes], [16, ounces, sour crea...
# 17   [[2, tablespoons, oil], [1, pound, chicken bre...
# 18   [[6, inches, flour tortillas], [16, ounces, re...
# 19   [[1, pound, flank steak], [1/4, cup, cornstarc...
# 20   [[2, pounds, skinless chicken breasts], [1/4, ...
# 21   [[6, slices, bread], [1, handful, spinach], [1...
# 22   [[4, None, salmon fillets], [1, tablespoon, un...
# 23   [[1, pound, ground beef], [1, cup, pasta sauce...
# 24   [[1/2, cup, butter], [1, tablespoon, oregano],...
# 25   [[12, None, corn tortillas], [3, None, large e...
# 26   [[16, ounces, salmon fillets], [1/4, cup, mapl...
# 27   [[4, None, summer squash], [1, tablespoon, oli...
# 28   [[4, None, bone-in pork chops], [1, teaspoon, ...
# 29   [[1, quart, vegetable stock], [2, cups, water]...
# ..                                                 ...
# 238  [[2/3, cup, all purpose flour], [1/2, teaspoon...
# 239  [[2, cups, water], [1 1/4, cups, quinoa], [1, ...
# 240  [[2, tablespoons, coconut oil], [2, cloves, ga...
# 241  [[2, cups, cooked quinoa], [3/4, cup, shredded...
# 242  [[4, pieces, naan], [2, teaspoons, olive oil],...
# 243  [[12, None, large eggs], [1, cup, cheddar chee...
# 244  [[1/4, cup, butter], [1, package, oreos], [1/2...
# 245  [[3, tablespoons, mayonnaise], [1, tablespoon,...
# 246  [[15, ounces, chickpeas], [1, None, lemon], [3...
# 247  [[4, None, onions], [2, None, green pepper], [...
# 248  [[4, None, chicken breasts], [1/4, cup, flour]...
# 249  [[1, head, cauliflower], [1, cup, sour cream],...
# 250  [[4, cups, cooked quinoa], [1/4, cup, pecorino...
# 251  [[2, pounds, skinless chicken breasts], [1, te...
# 252  [[2, pounds, frozen tater tots], [2, cups, che...
# 253  [[2, pounds, boneless pork chops], [None, None...
# 254  [[3, None, bananas], [2, cups, old-fashioned r...
# 255  [[4, None, boneless pork chops], [1, tablespoo...
# 256  [[8, ounces, elbow macaroni], [1, cup, hellman...
# 257  [[None, None, nonstick cooking spray], [1, cup...
# 258  [[2, None, flour tortillas], [2, None, eggs], ...
# 259  [[35, None, saltine crackers], [1, cup, unsalt...
# 260  [[2, cups, frozen blueberries], [1/2, cup, wal...
# 261  [[2, tablespoons, butter], [2, tablespoons, wa...
# 262  [[8, ounces, graham crackers], [24, ounces, fr...
# 263  [[6, ounces, vanilla yogurt], [1/2, cup, milk]...
# 264  [[3, cups, chicken], [16, ounces, frozen brocc...
# 265  [[1 1/2, pounds, salmon fillet], [2, None, gre...
# 266  [[2, tablespoons, butter], [16, ounces, frozen...
# 267  [[4, None, salmon fillets], [1, tablespoon, un...
#
#                                                  links  amazon  walmart  \
# 0    https://www.yummly.com/recipe/Quinoa-Tabbouleh...  19.848   10.548
# 1    https://www.yummly.com/recipe/Thai-Salmon-2408300  15.432    8.472
# 2    https://www.yummly.com/recipe/Coconut-Curry-Ca...  35.580   22.416
# 3    https://www.yummly.com/recipe/Korean-Vegetaria...  18.828   12.096
# 4    https://www.yummly.com/recipe/Braised-Chickpea...  32.148    8.016
# 5    https://www.yummly.com/recipe/Tuscan-Kale-With...   4.188    2.724
# 6    https://www.yummly.com/recipe/5-Ingredient-Che...   8.616    3.744
# 7    https://www.yummly.com/recipe/Oven-Baked-Pork-...   6.288    6.408
# 8    https://www.yummly.com/recipe/White-Chocolate-...  29.040   18.276
# 9    https://www.yummly.com/recipe/Perfect-Air-Frye...  26.616    9.168
# 10   https://www.yummly.com/recipe/Vegetarian-Chimi...  30.888   22.008
# 11   https://www.yummly.com/recipe/Garlic-Butter-Sh...  29.136    9.792
# 12   https://www.yummly.com/recipe/Mexican-lasagna-...  22.812   13.536
# 13   https://www.yummly.com/recipe/Bacon-cheeseburg...  27.444   16.236
# 14   https://www.yummly.com/recipe/Best-Green-Bean-...  15.300    6.888
# 15   https://www.yummly.com/recipe/Hamburger-Casser...  30.120   10.464
# 16   https://www.yummly.com/recipe/Bacon-Ranch-Pota...  22.560   10.008
# 17   https://www.yummly.com/recipe/Chicken-Curry-14...  26.016   17.928
# 18   https://www.yummly.com/recipe/Crisp-Bean-Burri...  21.264    5.712
# 19   https://www.yummly.com/recipe/Mongolian-Beef-7...  23.148   19.884
# 20   https://www.yummly.com/recipe/Sweet-and-Sour-G...  22.176   15.204
# 21   https://www.yummly.com/recipe/Breakfast-Toast-...  17.664    5.772
# 22   https://www.yummly.com/recipe/Easy-Garlic-Herb...  22.164    8.592
# 23   https://www.yummly.com/recipe/Italian-Crescent...  25.716   12.384
# 24   https://www.yummly.com/recipe/Bubba-Gump-Shrim...   5.964    3.576
# 25   https://www.yummly.com/recipe/Breakfast-Taquit...  30.648   17.028
# 26   https://www.yummly.com/recipe/Maple-Dijon-Salm...  32.496   18.720
# 27   https://www.yummly.com/recipe/Low-Carb-Zucchin...  28.788   11.532
# 28   https://www.yummly.com/recipe/Parmesan-Crusted...  26.172   15.780
# 29     https://www.yummly.com/recipe/Miso-Soup-2244697  13.620    9.480
# ..                                                 ...     ...      ...
# 238  https://www.yummly.com/recipe/Baked-Buffalo-Ch...  28.284   18.864
# 239  https://www.yummly.com/recipe/Curried-Quinoa-1...  28.476   21.384
# 240  https://www.yummly.com/recipe/Thai-Spicy-Noodl...  18.252   20.628
# 241  https://www.yummly.com/recipe/QUINOA-BURGER-11...  37.464   26.664
# 242  https://www.yummly.com/recipe/Quick-Margherita...  16.464   10.608
# 243  https://www.yummly.com/recipe/On-The-Go-Breakf...  29.952   11.412
# 244  https://www.yummly.com/recipe/Frozen-Oreo-Dess...  14.952    9.120
# 245  https://www.yummly.com/recipe/Amazingly-Moist-...  18.336    8.592
# 246  https://www.yummly.com/recipe/Healthy-Hummus-2...  13.152    5.064
# 247  https://www.yummly.com/recipe/Weight-Loss-Wond...  17.820   10.188
# 248  https://www.yummly.com/recipe/Easy-Pan-Seared-...  17.124   14.112
# 249  https://www.yummly.com/recipe/Loaded-Cauliflow...   8.904    4.572
# 250  https://www.yummly.com/recipe/Quinoa-Risotto-2...  23.112   12.420
# 251  https://www.yummly.com/recipe/Juicy-Oven-Baked...  16.416   13.452
# 252  https://www.yummly.com/recipe/Tater-Tot-Casser...  23.784   14.268
# 253  https://www.yummly.com/recipe/Garlic-Butter-Po...  15.504   11.748
# 254  https://www.yummly.com/recipe/Healthy-5-Ingred...  21.228   13.452
# 255  https://www.yummly.com/recipe/Parmesan-Baked-P...  14.316   10.128
# 256  https://www.yummly.com/recipe/Classic-macaroni...  19.980    8.028
# 257  https://www.yummly.com/recipe/5-Ingredient-Pou...  32.964   12.840
# 258  https://www.yummly.com/recipe/Breakfast-Quesad...  28.188   10.716
# 259  https://www.yummly.com/recipe/Christmas-Crack-...  27.264   13.104
# 260  https://www.yummly.com/recipe/Blueberry-Brain-...  25.620   13.812
# 261  https://www.yummly.com/recipe/Chocolate-Mug-Ca...  13.068    4.404
# 262  https://www.yummly.com/recipe/No-bake-Raspberr...  30.984   10.944
# 263  https://www.yummly.com/recipe/Banana-breakfast...  17.820    9.876
# 264  https://www.yummly.com/recipe/Easy-Chicken-Bro...  33.672   19.764
# 265  https://www.yummly.com/recipe/Firecracker-Salm...  20.268   15.072
# 266  https://www.yummly.com/recipe/Cheesy-Egg-And-H...  19.848   10.848
# 267  https://www.yummly.com/recipe/15-Minute-Baked-...  22.164    8.592
#
#      wholefoods
# 0        26.100
# 1        25.524
# 2        50.820
# 3        20.856
# 4        30.552
# 5         2.388
# 6        16.776
# 7        10.788
# 8        22.608
# 9        34.752
# 10       45.000
# 11       41.964
# 12       23.856
# 13       32.472
# 14       29.352
# 15       41.952
# 16       29.232
# 17       20.628
# 18       14.256
# 19       38.448
# 20       15.924
# 21       29.964
# 22       21.564
# 23       27.552
# 24       15.588
# 25       41.088
# 26       48.516
# 27       31.140
# 28       32.232
# 29       12.312
# ..          ...
# 238      36.432
# 239      43.284
# 240      31.404
# 241      52.932
# 242      27.540
# 243      46.380
# 244      21.576
# 245      35.964
# 246      11.352
# 247      13.140
# 248       8.256
# 249      17.124
# 250      34.752
# 251      14.736
# 252      30.192
# 253      16.764
# 254      15.792
# 255      28.644
# 256      17.856
# 257      27.156
# 258      22.080
# 259      28.260
# 260      43.500
# 261       7.896
# 262      27.900
# 263      10.128
# 264      37.980
# 265      34.032
# 266      25.392
# 267      21.564
#
# [268 rows x 14 columns]

# %% [markdown]
# ## 2. Recommender System

# %%
# Read in Recipies and URL
link = data[['title','links']]
# Read in User Rating Data
char_matrix = pd.read_csv('final_rating_data.csv')
char_matrix = char_matrix.drop(columns=['Unnamed: 0'])
char_matrix.head()
# Out:
#    10 Minute Healthy Crispy Chicken and avocado Wraps  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    10-Minute Blackened Salmon  15-Minute Baked Salmon with Lemon  \
# 0                         5.0                                NaN
# 1                         NaN                                NaN
# 2                         NaN                                5.0
# 3                         NaN                                NaN
# 4                         NaN                                NaN
#
#    20 Minute Honey Garlic Shrimp  20-Minute Lemon Pesto Penne  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            4.5                          NaN
# 4                            NaN                          NaN
#
#    3-Ingredient Healthy Banana Pancakes  30-Minute Vegetarian Meatballs  \
# 0                                   NaN                             5.0
# 1                                   NaN                             5.0
# 2                                   NaN                             NaN
# 3                                   NaN                             NaN
# 4                                   NaN                             NaN
#
#    4-Ingredient BBQ Baked Salmon  5 Ingredient Peanut Butter Energy Bites  \
# 0                            NaN                                      NaN
# 1                            NaN                                      NaN
# 2                            NaN                                      NaN
# 3                            5.0                                      4.0
# 4                            4.0                                      4.0
#
#    5-Ingredient Cheese Naan Pizzas  ...  Vegetable Ramen Pad Thai  \
# 0                              NaN  ...                       NaN
# 1                              NaN  ...                       NaN
# 2                              NaN  ...                       4.0
# 3                              NaN  ...                       NaN
# 4                              NaN  ...                       NaN
#
#    Vegetarian Chilli  Vegetarian Chimichangas  Vegetarian Enchilada  \
# 0                NaN                      NaN                   NaN
# 1                NaN                      NaN                   NaN
# 2                NaN                      NaN                   NaN
# 3                NaN                      NaN                   5.0
# 4                NaN                      4.0                   NaN
#
#    Vegetarian Gumbo  Weight Loss Wonder Soup  Weight Watchers Taco Casserole  \
# 0               NaN                      3.0                             NaN
# 1               NaN                      NaN                             NaN
# 2               NaN                      NaN                             NaN
# 3               NaN                      NaN                             NaN
# 4               NaN                      NaN                             NaN
#
#    White Chocolate-Raspberry Blender Muffins  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    Zesty Lime Shrimp and Avocado Salad  Zesty Quinoa with Broccoli and Cashews
# 0                                  NaN                                     NaN
# 1                                  NaN                                     NaN
# 2                                  NaN                                     NaN
# 3                                  NaN                                     NaN
# 4                                  NaN                                     1.0
#
# [5 rows x 265 columns]

# %%
# User input ratings
def user_input(data,link):
    # USER 1: 
    print('==================================================================')
    print('User1 Inputs:')
    print('==================================================================')
    # Generate Random recipies to rate
    dic = {}
    for x in range(10):
        index = random.randint(0,len(data.columns))
        recipie = data.columns[index]
        print(recipie,' : ',link.links[link['title']==recipie].values[0])
        rating = input('Enter Rating (1-5 stars): ')
        dic[recipie] = float(rating)
    # Unpack Rating and concat into main dataframe
    user = data.iloc[0]
    user[:] = np.nan
    for key,value in dic.items():
        user[key] = value
    temp = pd.DataFrame([user], index = ['user1'])
    df1 = pd.concat([temp, data])
    
    # USER 2:
    print('==================================================================')
    print('User2 Inputs:')
    print('==================================================================')
    # Generate Random recipies to rate
    dic = {}
    for x in range(10):
        index = random.randint(0,len(data.columns))
        recipie = data.columns[index]
        print(recipie,' : ',link.links[link['title']==recipie].values[0])
        rating = input('Enter Rating (1-5 stars): ')
        dic[recipie] = float(rating)
    # Unpack Rating and concat into main dataframe
    user = data.iloc[0]
    user[:] = np.nan
    for key,value in dic.items():
        user[key] = value
    temp = pd.DataFrame([user], index = ['user2'])
    final_df = pd.concat([temp, df1])
    return final_df

# %%
# Obtain User 1 & 2 Ratings
df = user_input(char_matrix,link)
# Out:
# ==================================================================
# User1 Inputs:
# ==================================================================
# Honey Dijon Garlic Chicken Breasts  :  https://www.yummly.com/recipe/Honey-Dijon-Garlic-Chicken-Breasts-2208217
# Enter Rating (1-5 stars): 5
# BBQ Chicken Naan Bread Pizza  :  https://www.yummly.com/recipe/BBQ-Chicken-Naan-Bread-Pizza-2127278
# Enter Rating (1-5 stars): 4
# Crunchy Detox Salad  :  https://www.yummly.com/recipe/Crunchy-Detox-Salad-2497438
# Enter Rating (1-5 stars): 5
# Black Bean-Quinoa Buddha Bowl  :  https://www.yummly.com/recipe/Black-Bean-Quinoa-Buddha-Bowl-2227717
# Enter Rating (1-5 stars): 3
# Easy 5-Ingredient Chicken Enchiladas  :  https://www.yummly.com/recipe/Easy-5-Ingredient-Chicken-Enchiladas-9073068
# Enter Rating (1-5 stars): 5
# Hamburger Casserole  :  https://www.yummly.com/recipe/Hamburger-Casserole-2286133
# Enter Rating (1-5 stars): 4
# Sauteed Ground Beef and Kale  :  https://www.yummly.com/recipe/Sauteed-Ground-Beef-and-Kale-1167062
# Enter Rating (1-5 stars): 3
# No-bake Raspberry Cheesecake Pots  :  https://www.yummly.com/recipe/No-bake-Raspberry-Cheesecake-Pots-2348480
# Enter Rating (1-5 stars): 2
# Bacon Cheeseburger Dip  :  https://www.yummly.com/recipe/Bacon-cheeseburger-dip-297605
# Enter Rating (1-5 stars): 5
# Apple Pie Smoothie  :  https://www.yummly.com/recipe/Apple-Pie-Smoothie-2202894
# Enter Rating (1-5 stars): 4
# ==================================================================
# User2 Inputs:
# ==================================================================
# Parmesan Baked Pork Chops  :  https://www.yummly.com/recipe/Parmesan-Baked-Pork-Chops-2092611
# Enter Rating (1-5 stars): 5
# Bubba Gump Shrimp  :  https://www.yummly.com/recipe/Bubba-Gump-Shrimp-2312171
# Enter Rating (1-5 stars): 3
# Garlic Mushroom Quinoa  :  https://www.yummly.com/recipe/Garlic-Mushroom-Quinoa-2271313
# Enter Rating (1-5 stars): 2
# Easy Korean Sticky Chicken  :  https://www.yummly.com/recipe/Easy-Korean-Sticky-Chicken-9101934
# Enter Rating (1-5 stars): 1
# Crunchy Detox Salad  :  https://www.yummly.com/recipe/Crunchy-Detox-Salad-2497438
# Enter Rating (1-5 stars): 2
# No Dough Pizza  :  https://www.yummly.com/recipe/No-Dough-Pizza-2406652
# Enter Rating (1-5 stars): 0
# Marry Me Chicken  :  https://www.yummly.com/recipe/Marry-Me-Chicken-2673329
# Enter Rating (1-5 stars): 2
# Strawberry Cheesecake Baked French Toast Casserole  :  https://www.yummly.com/recipe/Strawberry-Cheesecake-Baked-French-Toast-Casserole-2436600
# Enter Rating (1-5 stars): 1
# Slow-cooked Souperior Meatloaf  :  https://www.yummly.com/recipe/Slow-cooked-souperior-meatloaf-302982
# Enter Rating (1-5 stars): 3
# The Very Best Oven Baked Chicken Breast  :  https://www.yummly.com/recipe/The-Very-Best-Oven-Baked-Chicken-Breast-2507309
# Enter Rating (1-5 stars): 5

# %%
# ask user input for their allergies
allergies = list()
def user_input_allergies():
    # USER 1: 
    print('==================================================================')
    print('User1 Inputs:')
    print('==================================================================')
    a = input('Enter Your Allergies : ')
    element = a.split(',')
    for i in element:
        allergies.append(i)
        
    # USER 2:
    print('==================================================================')
    print('User2 Inputs:')
    print('==================================================================')
    a = input('Enter Your Allergies : ')
    element = a.split(',')
    for i in element:
        allergies.append(i)
    
    return allergies

# %%
# Obtain User 1 & 2 Allergies 
allergies = user_input_allergies()
# Out:
# ==================================================================
# User1 Inputs:
# ==================================================================
# Enter Your Allergies : mango,bean
# ==================================================================
# User2 Inputs:
# ==================================================================
# Enter Your Allergies : apple,beef

# %%
allergies
# Out:
# ['mango', 'bean', 'apple', 'beef']

# %%
ingredient = []
rating_index = []
for i in char_matrix.columns:
    temp = data[data['title']==i]
    ingredient.append(temp['ingredients'].values[0]) 
all_ingredients = [[]for i in range(len(ingredient))]
# find all the ingredients without unit
for rec in range(len(ingredient)):
    for ing in range(len(ingredient[rec])):
        all_ingredients[rec].append(ingredient[rec][ing][2].split())
# find the index of recipes which contain allergic ingredient
for ing in range(len(all_ingredients)):
    for i in all_ingredients[ing]:
        if any(key_word in i for key_word in allergies):
            rating_index.append(ing)

# %%
# Soft Impute missing data
df_filled = pd.DataFrame(SoftImpute().fit_transform(df.as_matrix()))
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# [SoftImpute] Max Singular Value of X_init = 145.715079
# [SoftImpute] Iter 1: observed MAE=0.366528 rank=106
# [SoftImpute] Iter 2: observed MAE=0.366451 rank=106
# [SoftImpute] Iter 3: observed MAE=0.366269 rank=106
# [SoftImpute] Iter 4: observed MAE=0.365634 rank=105
# [SoftImpute] Iter 5: observed MAE=0.364935 rank=105
# [SoftImpute] Iter 6: observed MAE=0.363909 rank=104
# [SoftImpute] Iter 7: observed MAE=0.361957 rank=102
# [SoftImpute] Iter 8: observed MAE=0.358827 rank=98
# [SoftImpute] Iter 9: observed MAE=0.355816 rank=96
# [SoftImpute] Iter 10: observed MAE=0.352760 rank=93
# [SoftImpute] Iter 11: observed MAE=0.349824 rank=91
# [SoftImpute] Iter 12: observed MAE=0.347356 rank=89
# [SoftImpute] Iter 13: observed MAE=0.344817 rank=88
# [SoftImpute] Iter 14: observed MAE=0.342946 rank=86
# [SoftImpute] Iter 15: observed MAE=0.340568 rank=84
# [SoftImpute] Iter 16: observed MAE=0.338937 rank=83
# [SoftImpute] Iter 17: observed MAE=0.336169 rank=80
# [SoftImpute] Iter 18: observed MAE=0.333806 rank=78
# [SoftImpute] Iter 19: observed MAE=0.331215 rank=76
# [SoftImpute] Iter 20: observed MAE=0.329371 rank=75
# [SoftImpute] Iter 21: observed MAE=0.327878 rank=74
# [SoftImpute] Iter 22: observed MAE=0.326118 rank=73
# [SoftImpute] Iter 23: observed MAE=0.324417 rank=72
# [SoftImpute] Iter 24: observed MAE=0.323078 rank=71
# [SoftImpute] Iter 25: observed MAE=0.321660 rank=69
# [SoftImpute] Iter 26: observed MAE=0.320004 rank=68
# [SoftImpute] Iter 27: observed MAE=0.317984 rank=66
# [SoftImpute] Iter 28: observed MAE=0.316586 rank=66
# [SoftImpute] Iter 29: observed MAE=0.315234 rank=64
# [SoftImpute] Iter 30: observed MAE=0.313939 rank=64
# [SoftImpute] Iter 31: observed MAE=0.312810 rank=63
# [SoftImpute] Iter 32: observed MAE=0.311863 rank=62
# [SoftImpute] Iter 33: observed MAE=0.310849 rank=61
# [SoftImpute] Iter 34: observed MAE=0.309845 rank=61
# [SoftImpute] Iter 35: observed MAE=0.308993 rank=60
# [SoftImpute] Iter 36: observed MAE=0.308215 rank=60
# [SoftImpute] Iter 37: observed MAE=0.307514 rank=59
# [SoftImpute] Iter 38: observed MAE=0.306706 rank=59
# [SoftImpute] Iter 39: observed MAE=0.305901 rank=58
# [SoftImpute] Iter 40: observed MAE=0.305208 rank=57
# [SoftImpute] Iter 41: observed MAE=0.304362 rank=56
# [SoftImpute] Iter 42: observed MAE=0.303328 rank=55
# [SoftImpute] Iter 43: observed MAE=0.302470 rank=55
# [SoftImpute] Iter 44: observed MAE=0.301824 rank=54
# [SoftImpute] Iter 45: observed MAE=0.301147 rank=54
# [SoftImpute] Iter 46: observed MAE=0.300713 rank=54
# [SoftImpute] Iter 47: observed MAE=0.300228 rank=52
# [SoftImpute] Iter 48: observed MAE=0.299318 rank=52
# [SoftImpute] Iter 49: observed MAE=0.298777 rank=51
# [SoftImpute] Iter 50: observed MAE=0.298059 rank=51
# [SoftImpute] Iter 51: observed MAE=0.297435 rank=50
# [SoftImpute] Iter 52: observed MAE=0.296940 rank=50
# [SoftImpute] Iter 53: observed MAE=0.296606 rank=50
# [SoftImpute] Iter 54: observed MAE=0.296339 rank=50
# [SoftImpute] Iter 55: observed MAE=0.296075 rank=49
# [SoftImpute] Iter 56: observed MAE=0.295516 rank=48
# [SoftImpute] Iter 57: observed MAE=0.295096 rank=48
# [SoftImpute] Iter 58: observed MAE=0.294810 rank=48
# [SoftImpute] Iter 59: observed MAE=0.294577 rank=48
# [SoftImpute] Iter 60: observed MAE=0.294391 rank=48
# [SoftImpute] Iter 61: observed MAE=0.294234 rank=48
# [SoftImpute] Iter 62: observed MAE=0.294081 rank=48
# [SoftImpute] Iter 63: observed MAE=0.293936 rank=48
# [SoftImpute] Iter 64: observed MAE=0.293791 rank=48
# [SoftImpute] Iter 65: observed MAE=0.293517 rank=46
# [SoftImpute] Iter 66: observed MAE=0.293008 rank=46
# [SoftImpute] Iter 67: observed MAE=0.292517 rank=45
# [SoftImpute] Iter 68: observed MAE=0.292173 rank=44
# [SoftImpute] Iter 69: observed MAE=0.291773 rank=44
# [SoftImpute] Iter 70: observed MAE=0.291523 rank=44
# [SoftImpute] Iter 71: observed MAE=0.291329 rank=44
# [SoftImpute] Iter 72: observed MAE=0.291181 rank=44
# [SoftImpute] Iter 73: observed MAE=0.291066 rank=44
# [SoftImpute] Iter 74: observed MAE=0.290825 rank=43
# [SoftImpute] Iter 75: observed MAE=0.290631 rank=43
# [SoftImpute] Iter 76: observed MAE=0.290425 rank=42
# [SoftImpute] Iter 77: observed MAE=0.290251 rank=42
# [SoftImpute] Iter 78: observed MAE=0.290120 rank=42
# [SoftImpute] Iter 79: observed MAE=0.290000 rank=42
# [SoftImpute] Iter 80: observed MAE=0.289891 rank=42
# [SoftImpute] Iter 81: observed MAE=0.289797 rank=42
# [SoftImpute] Iter 82: observed MAE=0.289713 rank=42
# [SoftImpute] Iter 83: observed MAE=0.289639 rank=42
# [SoftImpute] Iter 84: observed MAE=0.289500 rank=41
# [SoftImpute] Iter 85: observed MAE=0.289375 rank=41
# [SoftImpute] Iter 86: observed MAE=0.289283 rank=41
# [SoftImpute] Iter 87: observed MAE=0.289199 rank=41
# [SoftImpute] Iter 88: observed MAE=0.289121 rank=41
# [SoftImpute] Iter 89: observed MAE=0.289034 rank=40
# [SoftImpute] Iter 90: observed MAE=0.288862 rank=40
# [SoftImpute] Iter 91: observed MAE=0.288740 rank=40
# [SoftImpute] Iter 92: observed MAE=0.288642 rank=40
# [SoftImpute] Iter 93: observed MAE=0.288557 rank=40
# [SoftImpute] Iter 94: observed MAE=0.288477 rank=40
# [SoftImpute] Iter 95: observed MAE=0.288400 rank=40
# [SoftImpute] Iter 96: observed MAE=0.288321 rank=40
# [SoftImpute] Iter 97: observed MAE=0.288241 rank=40
# [SoftImpute] Iter 98: observed MAE=0.288158 rank=40
# [SoftImpute] Iter 99: observed MAE=0.288053 rank=39
# [SoftImpute] Iter 100: observed MAE=0.287950 rank=39
# [SoftImpute] Stopped after iteration 100 for lambda=2.914302

# %%
# 0 = User 2; 1 = User 1
for i in range(2):
    for j in rating_index:  
        df_filled[i][j] = 0
df_filled.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.768631  1.610823  1.656344  1.442383  1.417865  1.454180  1.057119
# 1  0.782586  2.180052  1.849801  1.739778  1.944354  1.133391  0.987717
# 2  0.782586  2.180052  1.849801  1.739778  1.944354  1.133391  0.987717
# 3  3.230636  4.785963  4.795564  4.335903  4.552920  3.489766  5.000000
# 4  3.067287  4.614206  5.000000  3.996984  4.042057  3.365220  3.142084
#
#         7         8         9    ...       255       256       257       258  \
# 0  1.577259  1.523188  1.877372  ...  2.159748  1.281746  1.129862  1.716503
# 1  1.678764  2.106190  1.305072  ...  1.046478  0.735836  0.912388  1.271222
# 2  1.678764  2.106190  1.305072  ...  1.046478  0.735836  0.912388  1.271222
# 3  4.740481  4.655663  4.484879  ...  3.867616  3.745121  4.087371  4.211912
# 4  4.151709  4.723610  4.721836  ...  4.000000  3.723016  4.182312  2.722269
#
#         259       260       261       262       263       264
# 0  1.488387  1.529942  1.665698  0.769901  1.733123  1.068380
# 1  1.279218  1.483695  1.119659  0.170888  1.633511  1.011952
# 2  1.279218  1.483695  1.119659  0.170888  1.633511  1.011952
# 3  3.274310  4.139742  4.444457  1.388556  4.231919  2.165153
# 4  3.301418  3.573475  3.752346  1.882407  4.592154  3.536112
#
# [5 rows x 265 columns]

# %% [markdown]
# ## 3. Optimization

# %%
#rating for user 0 and user 1
rating = df_filled[0:2].rename(index={0:1,1:0}).values.tolist()

# %%
# Set up input arrays for each category
calories = []
sodium = []
fat = []
protein = []
carbs = []
fiber = []
cook_time = []
amazon_price = []
wholefoods_price = []
walmart_price = []
K = 265
for i in char_matrix.columns:
    temp = data[data['title']==i]
    calories.append(temp['calories'].values[0])
    sodium.append(temp['sodium'].values[0])
    fat.append(temp['fat'].values[0])
    protein.append(temp['protein'].values[0])
    carbs.append(temp['carbs'].values[0])
    fiber.append(temp['fiber'].values[0])
    cook_time.append(temp['cook_time'].values[0])
    amazon_price.append(temp['amazon'].values[0])
    wholefoods_price.append(temp['wholefoods'].values[0])
    walmart_price.append(temp['walmart'].values[0])

# %%
# ask user inpput for their available time
K = 265
T = [[]for i in range(2)]
def user_input_time():
        # USER 1: 
    print('==================================================================')
    print('User1 Inputs:')
    print('==================================================================')
    for x in range(5):
        time = input('Enter Available time of day' + str(x+1) +' (minutes) : ')
        T[0].append(time)
    
    # USER 2:
    print('==================================================================')
    print('User2 Inputs:')
    print('==================================================================')
    for x in range(5):
        time = input('Enter Available time of day' + str(x+1) + ' (minutes) : ')
        T[1].append(time)
    # convert all the user input into Integer    
    for i in range(2):
        for j in range(5):
            T[i][j] = int(T[i][j])
    return T
T = user_input_time()
# Out:
# ==================================================================
# User1 Inputs:
# ==================================================================
# Enter Available time of day1 (minutes) : 89
# Enter Available time of day2 (minutes) : 78
# Enter Available time of day3 (minutes) : 90
# Enter Available time of day4 (minutes) : 78
# Enter Available time of day5 (minutes) : 89
# ==================================================================
# User2 Inputs:
# ==================================================================
# Enter Available time of day1 (minutes) : 123
# Enter Available time of day2 (minutes) : 78
# Enter Available time of day3 (minutes) : 98
# Enter Available time of day4 (minutes) : 78
# Enter Available time of day5 (minutes) : 56

# %%
T
# Out:
# [[89, 78, 90, 78, 89], [123, 78, 98, 78, 56]]

# %%
# ask user input for their nutrition intake and budget
height = list()
weight = list()
budget = list()
def user_input_nutrition():
    # USER 1: 
    print('==================================================================')
    print('User1 Inputs:')
    print('==================================================================')
    h = input('Enter Your Height (cm) : ')
    height.append(h)
    w = input('Enter Your Weight (kg) : ')
    weight.append(w)
    b = input('Enter Your budget : ')
    budget.append(b)
        
    # USER 2:
    print('==================================================================')
    print('User2 Inputs:')
    print('==================================================================')
    h = input('Enter Your Height (cm) : ')
    height.append(h)
    w = input('Enter Your Weight (kg) : ')
    weight.append(w)
    b = input('Enter Your budget : ')
    budget.append(b)
    
    return height,weight,budget
height,weight,budget = user_input_nutrition()
# Out:
# ==================================================================
# User1 Inputs:
# ==================================================================
# Enter Your Height (cm) : 175
# Enter Your Weight (kg) : 65
# Enter Your budget : 75
# ==================================================================
# User2 Inputs:
# ==================================================================
# Enter Your Height (cm) : 165
# Enter Your Weight (kg) : 55
# Enter Your budget : 75

# %%
# calculate the nutrition bound as well as the rating according to the user input
for i in range(2):
    height[i] = int(height[i])
    weight[i] = int(weight[i])
ratio = 0.4*(sum((height[i]/175*weight[i]/70) for i in range(2)))

# lower(1) and upper(2) bound of nutrient
cal_bound = [2000, 2500]
pro_bound = [30 ,50]
fat_bound = [65 , 80]
sod_bound = [1600 ,2400]
car_bound = [5, 100]
fib_bound = [0, 10]
for i in range(2):
    cal_bound[i] *= ratio
    pro_bound[i] *= ratio
    fat_bound[i] *= ratio
    sod_bound[i] *= ratio
    car_bound[i] *= ratio
    fib_bound[i] *= ratio

#Budget
B = sum(int(budget[i])for i in range(2))

#rating for user 0 and user 1
rating = df_filled.iloc[0:2].values.tolist()

# parameter for objective
alpha = 0.1

# %%
# Create a model instance
from docplex.mp.model import Model
MnM = Model(name='Meal Planning for the New Millennium')

# %%
# x_{itk} are binary variable
x = {(i,t,k): MnM.binary_var(name='x_{0}_{1}_{2}'.format(i,t,k)) for i in range(2) for t in range(5) for k in range(265)}

# %%
# time inequality
w = MnM.continuous_var(name='w', lb=0)

# %%
# five meals constraints, one meal per day
for t in range(5):
    MnM.add_constraint(MnM.sum(x[i,t,k] for i in range(2) for k in range(265)) == 1, ctname = 'subject to five_meals_total')


# nutrition lower bound
MnM.add_constraint(MnM.sum(calories[k]*x[i,t,k] for i in range(2) for t in range(5) for k in range(K)) >= cal_bound[0])
MnM.add_constraint(MnM.sum(protein[k]*x[i,t,k] for i in range(2) for t in range(5) for k in range(K)) >= pro_bound[0])
MnM.add_constraint(MnM.sum(fat[k]*x[i,t,k] for i in range(2) for t in range(5) for k in range(K)) >= fat_bound[0])
MnM.add_constraint(MnM.sum(sodium[k]*x[i,t,k] for i in range(2) for t in range(5) for k in range(K)) >= sod_bound[0])
MnM.add_constraint(MnM.sum(carbs[k]*x[i,t,k] for i in range(2) for t in range(5) for k in range(K)) >= car_bound[0])
MnM.add_constraint(MnM.sum(fiber[k]*x[i,t,k] for i in range(2) for t in range(5) for k in range(K)) >= fib_bound[0])

# nutrition upper bound
MnM.add_constraint(MnM.sum(calories[k]*x[i,t,k] for i in range(2) for t in range(5) for k in range(K)) <= cal_bound[1] )
MnM.add_constraint(MnM.sum(protein[k]*x[i,t,k] for i in range(2) for t in range(5) for k in range(K)) <= pro_bound[1] )
MnM.add_constraint(MnM.sum(fat[k]*x[i,t,k] for i in range(2) for t in range(5) for k in range(K)) <= fat_bound[1] )
MnM.add_constraint(MnM.sum(sodium[k]*x[i,t,k] for i in range(2) for t in range(5) for k in range(K)) <= sod_bound[1] )
MnM.add_constraint(MnM.sum(carbs[k]*x[i,t,k] for i in range(2) for t in range(5) for k in range(K)) >= car_bound[1])
MnM.add_constraint(MnM.sum(fiber[k]*x[i,t,k] for i in range(2) for t in range(5) for k in range(K)) >= fib_bound[1])

#budget constraint
MnM.add_constraint(MnM.sum(amazon_price[k]*x[i,t,k] for i in range(2) for t in range(5) for k in range(K)) <= B  )

        
# schedule time inequalities
MnM.add_constraint(MnM.sum(cook_time[k]* (x[0,t,k] - x[1,t,k]) for t in range(5) for k in range(K)) <= w)
MnM.add_constraint(MnM.sum(cook_time[k]* (x[0,t,k] - x[1,t,k]) for t in range(5) for k in range(K)) >= -w)

# meal diversity
for k in range(K):
    MnM.add_constraint(MnM.sum(x[i,t,k] for i in range(2) for t in range(5)) <= 1)

# schedule date constraint
for i in range(2):
    for t in range(5):
        MnM.add_constraint(MnM.sum(x[i,t,k]*cook_time[k] for k in range(265)) <= T[i][t])

# %%
# Decine the objective function
MnM.maximize(MnM.sum((rating[0][k]+rating[1][k])*x[i,t,k] for i in range(2) for t in range(5) for k in range(K)) - alpha*w)

# %%
#Solve the problem
MnM.print_information()
# Out:
# Model: Meal Planning for the New Millennium
#  - number of variables: 2651
#    - binary=2650, integer=0, continuous=1
#  - number of constraints: 175
#    - linear=175
#  - parameters: defaults
#  - problem type is: MILP

# %%
MnMs= MnM.solve(log_output=True)
assert MnMs
MnM.print_solution()
# Out:
# CPLEX Error  1016: Community Edition. Problem size limits exceeded. Purchase at http://ibm.biz/error1016.
# ---------------------------------------------------------------------------
# CplexSolverError                          Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\docplex\mp\cplex_engine.py in solve(self, mdl, parameters, lex_mipstart, lex_timelimits, lex_mipgaps)
#    2000             else:
# -> 2001                 cpx.solve()
#    2002
#
# D:\Anaconda\lib\site-packages\cplex\__init__.py in solve(self, paramsets)
#    1328             else:
# -> 1329                 _proc.mipopt(self._env._e, self._lp)
#    1330         elif self.quadratic_constraints.get_num() > 0:
#
# D:\Anaconda\lib\site-packages\cplex\_internal\_procedural.py in mipopt(env, lp)
#     691         status = CR.CPXXmipopt(env, lp)
# --> 692     check_status(env, status)
#     693
#
# D:\Anaconda\lib\site-packages\cplex\_internal\_procedural.py in __call__(self, env, status, from_cb)
#     235                     error_string = geterrorstring(env, status)
# --> 236             raise CplexSolverError(error_string, env, status)
#     237
#
# CplexSolverError: CPLEX Error  1016: Community Edition. Problem size limits exceeded. Purchase at http://ibm.biz/error1016.
#
# During handling of the above exception, another exception occurred:
#
# DOcplexLimitsExceeded                     Traceback (most recent call last)
# <ipython-input-42-fe5ab0b2f0e1> in <module>
# ----> 1 MnMs= MnM.solve(log_output=True)
#       2 assert MnMs
#       3 MnM.print_solution()
#
# ~\AppData\Roaming\Python\Python37\site-packages\docplex\mp\model.py in solve(self, **kwargs)
#    4178                 # if CPLEX is installed go for it
#    4179                 force_clean_before_solve = kwargs.get('clean_before_solve')
# -> 4180                 return self._solve_local(context, force_clean_before_solve, lex_timelimits, lex_mipgaps)
#    4181             elif have_credentials:
#    4182                 # no context passed as argument, no Cplex installed, try model's own context
#
# ~\AppData\Roaming\Python\Python37\site-packages\docplex\mp\model.py in _solve_local(self, context, force_clean_before_solve, lex_timelimits, lex_mipgaps)
#    4318         except DOcplexException as docpx_e:  # pragma: no cover
#    4319             self._set_solution(None)
# -> 4320             raise docpx_e
#    4321
#    4322         except Exception as e:
#
# ~\AppData\Roaming\Python\Python37\site-packages\docplex\mp\model.py in _solve_local(self, context, force_clean_before_solve, lex_timelimits, lex_mipgaps)
#    4305
#    4306             new_solution = self_engine.solve(self, parameters=parameters, lex_timelimits=lex_timelimits,
# -> 4307                                              lex_mipgaps=lex_mipgaps)
#    4308             has_solution = new_solution is not None
#    4309             self._set_solution(new_solution)
#
# ~\AppData\Roaming\Python\Python37\site-packages\docplex\mp\cplex_engine.py in solve(self, mdl, parameters, lex_mipstart, lex_timelimits, lex_mipgaps)
#    2030                 cpx_status = 1016
#    2031                 cpx_status_string = "Promotional version. Problem size limits exceeded., CPLEX code=1016."
# -> 2032                 self._model.fatal_ce_limits()
#    2033             else:
#    2034                 cpx_status, cpx_status_string = self._parse_cplex_exception_as_status(cpx_se)
#
# ~\AppData\Roaming\Python\Python37\site-packages\docplex\mp\model.py in fatal_ce_limits(self, *args)
#     889
#     890     def fatal_ce_limits(self, *args):
# --> 891         self._error_handler.fatal_limits_exceeded()
#     892
#     893     def error(self, msg, *args):
#
# ~\AppData\Roaming\Python\Python37\site-packages\docplex\mp\error_handler.py in fatal_limits_exceeded(self)
#     212     def fatal_limits_exceeded(self):
#     213         docplex_error_stop_here()
# --> 214         raise DOcplexLimitsExceeded()
#     215
#     216
#
# DOcplexLimitsExceeded: **** Promotional version. Problem size limits exceeded, CPLEX code=1016
